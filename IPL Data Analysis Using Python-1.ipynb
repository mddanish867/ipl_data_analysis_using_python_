# %% [markdown]
# # IPL Data Analysis Using Python Project-1

# %% [markdown]
# # what is Data Visualization?
# # Data visualization gives a clear idea of what information means to us by giving a visual context through maps or graphs. This makes data more natural for human mind comprehand and therefore makes it easier to identify trends and patterns ouliers within the large data set.

# %% [markdown]
# # Benifits of Data visualization

# %%
# Correlations in Relationship
# Trends over Time
# Frequency
# Examining the market
# risk and Reward

# %% [markdown]
# # Correlations in Relationships
# # A correlation is a measure or degree of relationship between two variables. As one of values increase the other set trends to increase then it is called a positive correlation. As one set of values increase the other set trends to decrease then it is called negative correlation

# %% [markdown]
# # Trends over time
# # A trends is what's hip or popular at a certain point in time. What a trend usually refers to a certain style in fashion or entertainment, there ciuld be a trend toward warmer tempratures.

# %% [markdown]
# # Frequency
# # Frequency analysis is a numerical which provides a clear representation of the global dynamics of many multi-dimensional systems and which is particularly usedful for system of 3 degree of freedom and more

# %% [markdown]
# # Examin the market
# # A market overview is a berief synopsis or industrial market. Its aim to provide acurrent snapshot of a market in order to better understand its features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("IPL Matches 2008-2020.csv",sep=",")
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
data.shape
# Out:
# (816, 17)

# %%
data.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
# method has lots of null value
# so we will drop it
data.drop(["method"], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  umpire1          816 non-null    object
#  15  umpire2          816 non-null    object
# dtypes: float64(1), int64(2), object(13)
# ...

# %%
# let's trying plotting cople of value and plot pie chart
# which team has won and how many times won

# %% [markdown]
# # Most wins

# %%
temp=pd.DataFrame({"Winner": data['winner']})
count_wins=temp.value_counts()
print(count_wins)
labels=[X[0] for X in count_wins.keys()]
# Out:
# Winner
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# dtype: int64

# %% [markdown]
# # plots

# %%
bar, ax=plt.subplots(figsize=(10,12))
ax=plt.pie(x=count_wins, autopct="%.1f%%", labels=labels)
plt.title("Most wins in IPL", fontsize=17)
plt.show()

# %% [markdown]
# # Most wins in Eliminator

# %%
sns.countplot(data['winner'][data['eliminator']=='Y'], data=data)
plt.title("Most wins in Eliminator ", fontsize=17)
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Toss decisions

# %%
teams=data['toss_winner'].unique()

#creating data frames
decision_making=pd.DataFrame([], columns=['Toss Winner','Decicion','Times'])

for id, element in enumerate(teams):
    temp_bat=data[(data['toss_winner']==element) & (data['toss_decision']=='bat')]
    temp_field=data[(data['toss_winner']==element) & (data['toss_decision']=='field')]
    
    #append to decision_making
    decision_making=decision_making.append({'Toss Winner':element,
                                            'Decision':'bat', 'Times':temp_bat['toss_winner'].count()},ignore_index=True)
    decision_making=decision_making.append({'Toss Winner':element,
                                            'Decision':'field', 'Times':temp_field['toss_winner'].count()},ignore_index=True)

# %%
decision_making
# Out:
#                     Toss Winner Decicion Times Decision
# 0   Royal Challengers Bangalore      NaN    24      bat
# 1   Royal Challengers Bangalore      NaN    24    field
# 2           Chennai Super Kings      NaN    51      bat
# 3           Chennai Super Kings      NaN    51    field
# 4              Rajasthan Royals      NaN    34      bat
# 5              Rajasthan Royals      NaN    34    field
# 6                Mumbai Indians      NaN    48      bat
# 7                Mumbai Indians      NaN    48    field
# 8               Deccan Chargers      NaN    24      bat
# 9               Deccan Chargers      NaN    24    field
# 10              Kings XI Punjab      NaN    27      bat
# 11              Kings XI Punjab      NaN    27    field
# 12        Kolkata Knight Riders      NaN    34      bat
# 13        Kolkata Knight Riders      NaN    34    field
# 14             Delhi Daredevils      NaN    29      bat
# 15             Delhi Daredevils      NaN    29    field
# ...

# %%
sns.catplot(x="Toss Winner", y="Times", hue="Decision", data=decision_making, kind='bar', height=5, aspect=2)
plt.xticks(rotation=90)
plt.title("Toss Decision of team")
plt.xlabel("IPL Teams")
plt.ylabel("Toss Decision")
plt.show()

# %% [markdown]
# # Famous venue

# %%
sns.barplot(x=data['venue'].value_counts().head(10).values,
           y=data['venue'].value_counts().head(10).index,
           data=data
           )
plt.title("Famous venue")
plt.xlabel("Venue_Count")
plt.ylabel("Venue")
plt.show()

# %% [markdown]
# # Top 10 Umpire_1

# %%
sns.barplot(x=data['umpire1'].value_counts().head(10).index,
           y=data['umpire1'].value_counts().head(10).values,
           )
plt.xlabel("Umpire1")
plt.ylabel("Match Count")
plt.title("Top 10 Umpire")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=data['umpire2'].value_counts().head(10).index,
           y=data['umpire2'].value_counts().head(10).values,
            data=data
           )
plt.xlabel("Match Count")
plt.ylabel("Umpire2")
plt.title("Top 10 Umpire")
plt.xticks(rotation=90)
plt.show()
